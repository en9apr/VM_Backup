# %%
   def diffusion(nt, nx, tmax, xmax, nu):
      """
      Returns the velocity field and distance for 1D linear convection
      """
      # Increments
      dt = tmax/(nt-1)
      dx = xmax/(nx-1)

      # Initialise data structures
      import numpy as np
      u = np.zeros((nx,nt))
      x = np.zeros(nx)

      # Boundary conditions
      u[0,:] = u[nx-1,:] = 1

      # Initial conditions      
      for i in range(1,nx-1):
         if(i > (nx-1)/4 and i < (nx-1)/2):
            u[i,0] = 2
         else:
            u[i,0] = 1

      # Loop
      for n in range(0,nt-1):
         for i in range(0,nx-1):
            u[i,n+1] = u[i,n] + nu*(dt/dx**2.0)*(u[i+1,n]-2.0*u[i,n]+u[i-1,n])

      # X Loop
      for i in range(0,nx):
         x[i] = i*dx

      return u, x
 
   def diffusion_solution(nt,nx,tmax,xmax,nu,L):
      """
      Returns the exact solution for Burgers' Equation
      """
      dt = tmax/(nt-1)
      dx = xmax/(nx-1)

      import numpy as np

      k=2.0*np.pi/L

      for i in range(0,nx-1):
         x[i] = i*dx

      for n in range(0,nt-1):
         for i in range(0,nx-1):
            u[i,n]=np.real(2.0*(np.exp(complex(0,k*x[i])))*(np.exp(-nu*k**2*n*dt)))

      return u, x

   def plot_diffusion(u,x,nt,title):
      """
      Plots the 1D velocity field
      """

      import matplotlib.pyplot as plt
      import matplotlib.cm as cm
      plt.figure()
      colour=iter(cm.rainbow(np.linspace(0,10,nt)))
      for i in range(0,nt,10):
         c=next(colour)
         plt.plot(x,u[:,i],c=c)
      w,y=diffusion_solution(151, 51, 0.5, 2.0, 0.1, 1.0)
      plt.plot(y,w[:,nt-2],color='k',linestyle='--')
      plt.xlabel('x (m)')
      plt.ylabel('u (m/s)')
      plt.ylim([0,3.0])
      plt.title(title)
      plt.show()

   u,x = diffusion(151, 51, 0.5, 2.0, 0.1)
   plot_diffusion(u,x,151,'Figure 1: nu=0.1, nt=151, nx=51, tmax=0.5s')

   u,x = diffusion(151, 79, 0.5, 2.0, 0.1)
   plot_diffusion(u,x,151,'Figure 2: nu=0.1, nt=151, nx=79, tmax=0.5s')

   u,x = diffusion(151, 51, 1.217, 2.0, 0.1)
   plot_diffusion(u,x,151,'Figure 3: nu=0.1, nt=151, nx=51, tmax=1.217s')

   def diffusion(nt, nx, tmax, xmax, nu):
      """
      Returns the velocity field and distance for 1D linear convection
      """
      # Increments
      dt = tmax/(nt-1)
      dx = xmax/(nx-1)

      # Initialise data structures
      import numpy as np
      u = np.zeros((nx,nt))
      x = np.zeros(nx)

      # Boundary conditions
      u[0,:] = u[nx-1,:] = 1

      # Initial conditions      
      for i in range(1,nx-1):
         if(i > (nx-1)/4 and i < (nx-1)/2):
            u[i,0] = 2
         else:
            u[i,0] = 1

      # Loop
      for n in range(0,nt-1):
         for i in range(0,nx-1):
            u[i,n+1] = u[i,n] + nu*(dt/dx**2.0)*(u[i+1,n]-2.0*u[i,n]+u[i-1,n])

      # X Loop
      for i in range(0,nx):
         x[i] = i*dx

      return u, x
 
   def diffusion_solution(nt,nx,tmax,xmax,nu,L):
      """
      Returns the exact solution for Burgers' Equation
      """
      dt = tmax/(nt-1)
      dx = xmax/(nx-1)

      import numpy as np

      k=2.0*np.pi/L

      for i in range(0,nx-1):
         x[i] = i*dx

      for n in range(0,nt-1):
         for i in range(0,nx-1):
            u[i,n]=np.real(2.0*(np.exp(complex(0,k*x[i])))*(np.exp(-nu*k**2*n*dt)))

      return u, x

   def plot_diffusion(u,x,nt,title):
      """
      Plots the 1D velocity field
      """

      import matplotlib.pyplot as plt
      import matplotlib.cm as cm
      plt.figure()
      colour=iter(cm.rainbow(np.linspace(0,10,nt)))
      for i in range(0,nt,10):
         c=next(colour)
         plt.plot(x,u[:,i],c=c)
      y,w=diffusion_solution(151, 51, 0.5, 2.0, 0.1, 1.0)
      plt.plot(y,w[:,nt-1],color='k',linestyle='--')
      plt.xlabel('x (m)')
      plt.ylabel('u (m/s)')
      plt.ylim([0,3.0])
      plt.title(title)
      plt.show()

   def plot_final(u,x,nt,title):
      """
      Plots the 1D velocity field
      """

      import matplotlib.pyplot as plt
      import matplotlib.cm as cm
      plt.figure()
      plt.plot(x,u[:,nt-1],color='k',linestyle='--')
     
      plt.xlabel('x (m)')
      plt.ylabel('u (m/s)')
      plt.ylim([0,3.0])
      plt.title(title)
      plt.show()

   u,x = diffusion(151, 51, 0.5, 2.0, 0.1)
   plot_diffusion(u,x,151,'Figure 1: nu=0.1, nt=151, nx=51, tmax=0.5s')

   u,x = diffusion(151, 79, 0.5, 2.0, 0.1)
   plot_diffusion(u,x,151,'Figure 2: nu=0.1, nt=151, nx=79, tmax=0.5s')

   u,x = diffusion(151, 51, 1.217, 2.0, 0.1)
   plot_diffusion(u,x,151,'Figure 3: nu=0.1, nt=151, nx=51, tmax=1.217s')

   y,w=diffusion_solution(151, 51, 0.5, 2.0, 0.1, 1.0)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-15-185bc9f1a231> in <module>()
#     173
#     174 u,x = diffusion(151, 51, 0.5, 2.0, 0.1)
# --> 175 plot_diffusion(u,x,151,'Figure 1: nu=0.1, nt=151, nx=51, tmax=0.5s')
#     176
#     177 u,x = diffusion(151, 79, 0.5, 2.0, 0.1)
#
# <ipython-input-15-185bc9f1a231> in plot_diffusion(u, x, nt, title)
#     149       plt.plot(x,u[:,i],c=c)
#     150    y,w=diffusion_solution(151, 51, 0.5, 2.0, 0.1, 1.0)
# --> 151    plt.plot(y,w[:,nt-1],color='k',linestyle='--')
#     152    plt.xlabel('x (m)')
#     153    plt.ylabel('u (m/s)')
#
# IndexError: invalid index

# %%
len(w)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-5cd91cc38d09> in <module>()
# ----> 1 len(w)
#
# NameError: name 'w' is not defined
