# %% [markdown]
# ### 2.0 Integral Form of the Conservation of Momentum ###
#
# **2.0.1** For a system:
#
# $$ \vec F = {D \over D t} \int_{SYS} \vec V dM $$

# %% [markdown]
# **2.0.2** For a control volume (via Reynolds Transport Theorem):
#
# $$ \sum \vec F_{CV} = {\partial \over \partial t} \int_{CV} \vec V \rho dV + \int_{CS} \vec V \rho \vec V \cdot \hat n dA  $$

# %% [markdown]
# ### 2.1 Differential Form of the Conservation of Momentum ###

# %% [markdown]
# **2.1.0** For the left-hand side of the equation there are:
#
# *2.1.0.1* Body forces - weight for an element $ \delta m$:
#
# $$ \delta \vec F = {D \over D t} \vec V \delta m = \delta m {D \over {Dt}} \vec V = \delta m \cdot \vec a$$
#
# $$ \delta \vec F_b = \delta m \cdot \vec g $$

# %%
from IPython.display import Image
Image(filename='/home/uwhpsc/Downloads/force_diagram_2.png')

# %% [markdown]
# *2.1.0.2* Normal force ($\delta F_n$ : normal to $\delta A$)
#
#
# *2.1.0.3* Tangential force ($\delta F_1$, $\delta F_2$ : tangential to $\delta A$)
#
# *2.1.0.4* Normal stress
#
# $$\sigma_n = \lim_{\delta A \to 0} {\delta F_n \over \delta A}$$
#
# *2.1.0.5* Tangential stress
#
# $$\tau_1 = \lim_{\delta A \to 0} {\delta F_1 \over \delta A}$$
#
# $$\tau_2 = \lim_{\delta A \to 0} {\delta F_2 \over \delta A}$$

# %%
Image(filename='/home/uwhpsc/Downloads/stress_diagram_3.png')

# %% [markdown]
# *2.1.0.6* With reference to a coordinate system:
#
# *2.1.0.7* Normal stress : $\sigma_{xx}$
#
# *2.1.0.8* Shear stress : $\tau_{xy}$ $\tau_{xz}$
#
# *2.1.0.9* Subscript notation: 1st subscript refers to the direction of the normal vector
#
# *2.1.0.10* Subscript notation: 2nd subscript refers to the direction of the stress vector
#
# *2.1.0.11* Sign convention: Normal Stress is positive if it's in the same direction as the outward normal vector
#
# *2.1.0.12* Sign convention: Shear Stress is positive if it's in the same direction as the coordinate system w.r.t the outward normal vector

# %%
Image(filename='/home/uwhpsc/Downloads/stress_diagram_5.png')

# %% [markdown]
# 2.1.0.13 Conservation of Momemtum in x-direction:
#
# $$ \delta F_{sx} = \left( {\partial \sigma_{xx} \over \partial x} + {\partial \tau_{yx} \over \partial y} + {\partial \tau_{zx} \over \partial z} \right) \delta x \delta y \delta z$$
#
# 2.1.0.14 Conservation of Momemtum in y-direction:
#
# $$ \delta F_{sy} = \left( {\partial \tau_{xy}  \over \partial x} + {\partial \sigma_{yy} \over \partial y} + {\partial \tau_{zy} \over \partial z} \right) \delta x \delta y \delta z$$
#
# 2.1.0.15 Conservation of Momemtum in z-direction:
#
# $$ \delta F_{sz} = \left( {\partial \tau_{xz} \over \partial x} + {\partial \tau_{yz} \over \partial y} + {\partial \sigma_{zz} \over \partial z} \right) \delta x \delta y \delta z$$

# %% [markdown]
# **2.1.1** Equation of motion:
#
# $$\delta \vec F = \delta m \cdot \vec a $$
#
# $$\delta m = \rho \delta x \delta y \delta z $$
#
# $$ \rho g_x + {\partial \sigma_{xx} \over \partial x} + {\partial \tau_{yx} \over \partial y} + {\partial \tau_{zx} \over \partial z} = \rho \left ( {\partial u \over \partial t} + u{\partial u \over \partial x} + v {\partial u \over \partial y} + w {\partial u \over \partial z} \right ) $$
#
# $$ \rho g_y + {\partial \tau_{xy} \over \partial x} + {\partial \sigma_{yy} \over \partial y} + {\partial \tau_{zy} \over \partial z} = \rho \left ( {\partial v \over \partial t} + u {\partial v \over \partial x} + v {\partial v \over \partial y} + w {\partial v \over \partial z} \right ) $$
#
# $$ \rho g_z + {\partial \tau_{xz} \over \partial x} + {\partial \tau_{yz} \over \partial y} + {\partial \sigma_{zz} \over \partial z} = \rho \left ( {\partial w \over \partial t} + u {\partial w \over \partial x} + v {\partial w \over \partial y} + w {\partial w \over \partial z} \right ) $$

# %% [markdown]
# *2.1.1.0* Three equations + continuity = Four equations
#
# *2.1.1.1* Unknowns: u, v, w and nine stresses = Twelve unknowns - need more infomation

# %% [markdown]
# *2.1.1.2* Invisid flow - no shearing stresses $$ \sigma_{xx} = \sigma_{yy} = \sigma_{zz}  = -p$$

# %% [markdown]
# *2.1.1.3* Euler's Equation in the x-direction:
#
# $$ \rho g_x - {\partial p \over \partial x} = \rho \left ( {\partial u \over \partial t} + u {\partial u \over \partial x} + v {\partial u \over \partial y} + w {\partial u \over \partial z} \right ) $$

# %% [markdown]
# *2.1.1.4* Vector Notation:
#
# $$ \rho \vec g-  \nabla p = \rho \left ( {\partial \over \partial t} \vec V + \vec V (\nabla \cdot \vec V) \right ) $$

# %% [markdown]
# where the del operator like a row vector multiplied by a velocity vector as a column vector via dot product

# %% [markdown]
# that then gets scalar multipied by the velocity vector again
